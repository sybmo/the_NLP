# %%
import pandas as pd
import checklist
from allennlp_models.pretrained import load_predictor
from allennlp_models.pretrained import get_pretrained_models
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.pred_wrapper import PredictorWrapper

# %%
## define the amount of samples PER COUNTRY

nsamples = 100

# %%
editor = Editor()

# %%
srl_predictor = load_predictor('structured-prediction-srl-bert')
# Out:
# lerc is not a registered model.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
chinese_cities = list(editor.lexicons['country_city']['China'])
us_cities = list(editor.lexicons['country_city']['United_States'])
russian_cities = list(editor.lexicons['country_city']['Russia'])

china_names_male = editor.lexicons.male_from.China
us_names_male = editor.lexicons.male_from.United_States
russian_names_male = editor.lexicons.male_from.Russia

editor.add_lexicon("china_names_male", china_names_male, overwrite=True)
editor.add_lexicon("us_names_male", us_names_male, overwrite=True)
editor.add_lexicon("russian_names_male", russian_names_male, overwrite=True)

editor.add_lexicon("chinese_cities", chinese_cities, overwrite=True)
editor.add_lexicon("us_cities", us_cities, overwrite=True)
editor.add_lexicon("russian_cities", russian_cities, overwrite=True)

chinese_china = editor.template("{china_names_male} walks in {chinese_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)
usa_usa = editor.template("{us_names_male} walks in {us_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)
russian_russia = editor.template("{russian_names_male} walks in {russian_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)

# %%
def make_data_fairness(amount_per_format):
    list_japan = []
    list_usa = []
    list_france = []
    
    editor = Editor()
    
    japanese_cities = list(editor.lexicons['country_city']['Japan'])
    us_cities = list(editor.lexicons['country_city']['United_States'])
    french_cities = list(editor.lexicons['country_city']['France'])

    japanese_names_male = editor.lexicons.male_from.Japan
    us_names_male = editor.lexicons.male_from.United_States
    french_names_male = editor.lexicons.male_from.France

    editor.add_lexicon("japanese_names_male",japanese_names_male, overwrite=True)
    editor.add_lexicon("us_names_male", us_names_male, overwrite=True)
    editor.add_lexicon("french_names_male", french_names_male, overwrite=True)

    editor.add_lexicon("japanese_cities", japanese_cities, overwrite=True)
    editor.add_lexicon("us_cities", us_cities, overwrite=True)
    editor.add_lexicon("french_cities", french_cities, overwrite=True)

    japanese_japan = editor.template("{japanese_names_male} walks in {japanese_cities}.", 
                                    meta=True, 
                                    nsamples=amount_per_format, 
                                    remove_duplicates=True, 
                                    seed=18)
    list_japan.append(japanese_japan['data'])
    list_japan = [x for xs in list_japan for x in xs]
    
    
    usa_usa = editor.template("{us_names_male} walks in {us_cities}.", 
                              meta=True, 
                              nsamples=amount_per_format, 
                              remove_duplicates=True, 
                              seed=18)
    list_usa.append(usa_usa['data'])
    list_usa = [x for xs in list_usa for x in xs]
    
    french_france = editor.template("{french_names_male} walks in {french_cities}.", 
                                     meta=True, 
                                     nsamples=amount_per_format, 
                                     remove_duplicates=True, 
                                     seed=18)
    list_france.append(french_france['data'])
    list_france = [x for xs in list_france for x in xs]
    return list_japan, list_usa, list_france

# %%
def get_pp_tags(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_tags = output['verbs'][0]['tags']#['verb']#[0]['tags']
    else:
        pp_tags = sentence
    return pp_tags

def get_pp_descr(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_descr = output['verbs'][0]['description']
    else:
        pp_descr = sentence
    return pp_descr

def find_final_min_one_arg(list_of_arg):
    if list_of_arg:
        element = list_of_arg[-2]
    else:
        element = 'missed_verb'
    return element

# %%
list_japan, list_usa, list_france =  make_data_fairness(nsamples)

# %%
srl_predictor = load_predictor('structured-prediction-srl-bert')

df_japan = pd.DataFrame(list_japan)
df_japan['pp_tag'] = df_japan[0].apply(get_pp_tags)
df_japan['pp_descr'] = df_japan[0].apply(get_pp_descr)
df_japan[1] = df_japan['pp_tag'].apply(find_final_min_one_arg)

df_usa = pd.DataFrame(list_usa)
df_usa['pp_tag'] = df_usa[0].apply(get_pp_tags)
df_usa['pp_descr'] = df_usa[0].apply(get_pp_descr)
df_usa[1] = df_usa['pp_tag'].apply(find_final_min_one_arg)

df_france = pd.DataFrame(list_france)
df_france['pp_tag'] = df_france[0].apply(get_pp_tags)
df_france['pp_descr'] = df_france[0].apply(get_pp_descr)
df_france[1] = df_france['pp_tag'].apply(find_final_min_one_arg)
# Out:
# lerc is not a registered model.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
df_japan[0].to_csv("../datasets/fairness/japan.txt", header=None, index=False)
df_usa[0].to_csv("../datasets/fairness/usa.txt", header=None, index=False)
df_france[0].to_csv("../datasets/fairness/france.txt", header=None, index=False)

df_japan.to_csv("../results/fairness/japan_results_bert.csv")
df_usa.to_csv("../results/fairness/usa_results_bert.csv")
df_france.to_csv("../results/fairness/france_results_bert.csv")

# %%
error_japan_bert = df_japan[df_japan[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_usa_bert = df_usa[df_usa[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_france_bert = df_france[df_france[1] != 'I-ARGM-LOC'].sort_values(by=[1])

# %%
error_japan_bert[[0,'pp_descr']]
# Out:
#                              0  \
# 87           まさる walks in Yao.
# 83         けいじ walks in Kōchi.
# 5           あつし walks in Kōbe.
# 64  すすむ walks in Higashiōsaka.
# 62    まさる walks in Kitakyūshū.
# 8           たけし walks in Kōbe.
# 56       あきら walks in Machida.
# 15         つよし walks in Suita.
# 35      みのる walks in Kōriyama.
# 28      ひろし walks in Kōriyama.
# 27  たけお walks in Higashiōsaka.
# 0     しんいち walks in Amagasaki.
# 37      こういち walks in Tsukuba.
# 29        まさお walks in Kurume.
# 43        だいすけ walks in Chiba.
# 25         えいじ walks in Fuchū.
# 4     だいすけ walks in Yokkaichi.
# 66        とおる walks in Nagoya.
# 73           太郎 walks in Naha.
# 70          ケン walks in Akita.
# 6    みつお walks in Nishinomiya.
# 7       まこと walks in Yokohama.
# 74    ひろき walks in Tokorozawa.
# 9    よしたか walks in Utsunomiya.
# 84     たけお walks in Tokushima.
# 92          しんじ walks in Naha.
# 38    よしあき walks in Tokushima.
# 12        まさひこ walks in Ōsaka.
# 16       まさし walks in Kashiwa.
# 33         のぶお walks in Ōsaka.
# 51     たつお walks in Fukushima.
# 78     のぶお walks in Fukushima.
# 85     まさし walks in Kurashiki.
# 81         のぼる walks in Iwaki.
# 98     まさのり walks in Kawasaki.
# 50       まさのり walks in Nagano.
# 1           としお walks in Mito.
# 72       まこと walks in Sapporo.
# 23     かずお walks in Matsumoto.
# 94         まさひこ walks in Ōtsu.
# 59    こうじ walks in Kitakyūshū.
# 46    みつお walks in Kitakyūshū.
#
#                                              pp_descr
# 87        [ARG0: まさる] [V: walks] [ARGM-MNR: in Yao] .
# 83      [ARG0: けいじ] [V: walks] [ARGM-MNR: in Kōchi] .
# 5        [ARG0: あつし] [V: walks] [ARGM-MNR: in Kōbe] .
# 64  [ARG0: すすむ] [V: walks] [ARGM-MNR: in Higashiōs...
# 62  [ARG0: まさる] [V: walks] [ARGM-MNR: in Kitakyūsh...
# 8        [ARG0: たけし] [V: walks] [ARGM-MNR: in Kōbe] .
# 56    [ARG0: あきら] [V: walks] [ARGM-MNR: in Machida] .
# 15      [ARG0: つよし] [V: walks] [ARGM-MNR: in Suita] .
# 35   [ARG0: みのる] [V: walks] [ARGM-MNR: in Kōriyama] .
# 28   [ARG0: ひろし] [V: walks] [ARGM-MNR: in Kōriyama] .
# 27  [ARG0: たけお] [V: walks] [ARGM-MNR: in Higashiōs...
# 0                      [V: しんいち] walks in Amagasaki .
# 37                       [V: こういち] walks in Tsukuba .
# 29                         [V: まさお] walks in Kurume .
# 43                         [V: だいすけ] walks in Chiba .
# 25                          [V: えいじ] walks in Fuchū .
# 4                      [V: だいすけ] walks in Yokkaichi .
# 66                               とおる walks in Nagoya.
# 73                                  太郎 walks in Naha.
# 70                                 ケン walks in Akita.
# 6                           みつお walks in Nishinomiya.
# 7                              まこと walks in Yokohama.
# 74                           ひろき walks in Tokorozawa.
# 9                           よしたか walks in Utsunomiya.
# 84                            たけお walks in Tokushima.
# 92                                 しんじ walks in Naha.
# 38                           よしあき walks in Tokushima.
# 12                               まさひこ walks in Ōsaka.
# 16                              まさし walks in Kashiwa.
# 33                                のぶお walks in Ōsaka.
# 51                            たつお walks in Fukushima.
# 78                            のぶお walks in Fukushima.
# 85                            まさし walks in Kurashiki.
# 81                                のぼる walks in Iwaki.
# 98                            まさのり walks in Kawasaki.
# 50                              まさのり walks in Nagano.
# 1                                  としお walks in Mito.
# 72                              まこと walks in Sapporo.
# 23                            かずお walks in Matsumoto.
# 94                                まさひこ walks in Ōtsu.
# 59                           こうじ walks in Kitakyūshū.
# 46                           みつお walks in Kitakyūshū.

# %%
error_usa_bert[[0,'pp_descr']]
# Out:
#                            0  \
# 20    Matt walks in Garland.
# 25  Daniel walks in Wichita.
# 42    Rick walks in Garland.
# 50    Jack walks in Madison.
# 55     Sam walks in Wichita.
# 97       Fred walks in Mesa.
#
#                                              pp_descr
# 20   [ARG0: Matt] [V: walks] [ARGM-MNR: in Garland] .
# 25  [ARG0: Daniel] [V: walks] [ARGM-MNR: in Wichit...
# 42   [ARG0: Rick] [V: walks] [ARGM-MNR: in Garland] .
# 50   [ARG0: Jack] [V: walks] [ARGM-MNR: in Madison] .
# 55    [ARG0: Sam] [V: walks] [ARGM-MNR: in Wichita] .
# 97                                Fred walks in Mesa.

# %%
error_japan_bert[[0,'pp_descr']]
# Out:
#                              0  \
# 87           まさる walks in Yao.
# 83         けいじ walks in Kōchi.
# 5           あつし walks in Kōbe.
# 64  すすむ walks in Higashiōsaka.
# 62    まさる walks in Kitakyūshū.
# 8           たけし walks in Kōbe.
# 56       あきら walks in Machida.
# 15         つよし walks in Suita.
# 35      みのる walks in Kōriyama.
# 28      ひろし walks in Kōriyama.
# 27  たけお walks in Higashiōsaka.
# 0     しんいち walks in Amagasaki.
# 37      こういち walks in Tsukuba.
# 29        まさお walks in Kurume.
# 43        だいすけ walks in Chiba.
# 25         えいじ walks in Fuchū.
# 4     だいすけ walks in Yokkaichi.
# 66        とおる walks in Nagoya.
# 73           太郎 walks in Naha.
# 70          ケン walks in Akita.
# 6    みつお walks in Nishinomiya.
# 7       まこと walks in Yokohama.
# 74    ひろき walks in Tokorozawa.
# 9    よしたか walks in Utsunomiya.
# 84     たけお walks in Tokushima.
# 92          しんじ walks in Naha.
# 38    よしあき walks in Tokushima.
# 12        まさひこ walks in Ōsaka.
# 16       まさし walks in Kashiwa.
# 33         のぶお walks in Ōsaka.
# 51     たつお walks in Fukushima.
# 78     のぶお walks in Fukushima.
# 85     まさし walks in Kurashiki.
# 81         のぼる walks in Iwaki.
# 98     まさのり walks in Kawasaki.
# 50       まさのり walks in Nagano.
# 1           としお walks in Mito.
# 72       まこと walks in Sapporo.
# 23     かずお walks in Matsumoto.
# 94         まさひこ walks in Ōtsu.
# 59    こうじ walks in Kitakyūshū.
# 46    みつお walks in Kitakyūshū.
#
#                                              pp_descr
# 87        [ARG0: まさる] [V: walks] [ARGM-MNR: in Yao] .
# 83      [ARG0: けいじ] [V: walks] [ARGM-MNR: in Kōchi] .
# 5        [ARG0: あつし] [V: walks] [ARGM-MNR: in Kōbe] .
# 64  [ARG0: すすむ] [V: walks] [ARGM-MNR: in Higashiōs...
# 62  [ARG0: まさる] [V: walks] [ARGM-MNR: in Kitakyūsh...
# 8        [ARG0: たけし] [V: walks] [ARGM-MNR: in Kōbe] .
# 56    [ARG0: あきら] [V: walks] [ARGM-MNR: in Machida] .
# 15      [ARG0: つよし] [V: walks] [ARGM-MNR: in Suita] .
# 35   [ARG0: みのる] [V: walks] [ARGM-MNR: in Kōriyama] .
# 28   [ARG0: ひろし] [V: walks] [ARGM-MNR: in Kōriyama] .
# 27  [ARG0: たけお] [V: walks] [ARGM-MNR: in Higashiōs...
# 0                      [V: しんいち] walks in Amagasaki .
# 37                       [V: こういち] walks in Tsukuba .
# 29                         [V: まさお] walks in Kurume .
# 43                         [V: だいすけ] walks in Chiba .
# 25                          [V: えいじ] walks in Fuchū .
# 4                      [V: だいすけ] walks in Yokkaichi .
# 66                               とおる walks in Nagoya.
# 73                                  太郎 walks in Naha.
# 70                                 ケン walks in Akita.
# 6                           みつお walks in Nishinomiya.
# 7                              まこと walks in Yokohama.
# 74                           ひろき walks in Tokorozawa.
# 9                           よしたか walks in Utsunomiya.
# 84                            たけお walks in Tokushima.
# 92                                 しんじ walks in Naha.
# 38                           よしあき walks in Tokushima.
# 12                               まさひこ walks in Ōsaka.
# 16                              まさし walks in Kashiwa.
# 33                                のぶお walks in Ōsaka.
# 51                            たつお walks in Fukushima.
# 78                            のぶお walks in Fukushima.
# 85                            まさし walks in Kurashiki.
# 81                                のぼる walks in Iwaki.
# 98                            まさのり walks in Kawasaki.
# 50                              まさのり walks in Nagano.
# 1                                  としお walks in Mito.
# 72                              まこと walks in Sapporo.
# 23                            かずお walks in Matsumoto.
# 94                                まさひこ walks in Ōtsu.
# 59                           こうじ walks in Kitakyūshū.
# 46                           みつお walks in Kitakyūshū.

# %%
error_rate_france_bert = len(df_france[df_france[1]!='I-ARGM-LOC'])/len(df_france)*100
error_rate_japan_bert = len(df_japan[df_japan[1]!='I-ARGM-LOC'])/len(df_japan)*100
error_rate_usa_bert = len(df_usa[df_usa[1]!='I-ARGM-LOC'])/len(df_usa)*100

# %%
srl_predictor = load_predictor('structured-prediction-srl')

df_japan = pd.DataFrame(list_japan)
df_japan['pp_tag'] = df_japan[0].apply(get_pp_tags)
df_japan['pp_descr'] = df_japan[0].apply(get_pp_descr)
df_japan[1] = df_japan['pp_tag'].apply(find_final_min_one_arg)

df_usa = pd.DataFrame(list_usa)
df_usa['pp_tag'] = df_usa[0].apply(get_pp_tags)
df_usa['pp_descr'] = df_usa[0].apply(get_pp_descr)
df_usa[1] = df_usa['pp_tag'].apply(find_final_min_one_arg)

df_france = pd.DataFrame(list_france)
df_france['pp_tag'] = df_france[0].apply(get_pp_tags)
df_france['pp_descr'] = df_france[0].apply(get_pp_descr)
df_france[1] = df_france['pp_tag'].apply(find_final_min_one_arg)
# Out:
# lerc is not a registered model.

# %%
df_japan.to_csv("../results/fairness/japan_results_bilstm.csv")
df_usa.to_csv("../results/fairness/usa_results_bilstm.csv")
df_france.to_csv("../results/fairness/france_results_bilstm.csv")

# %%
error_japan_bilstm = df_japan[df_japan[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_usa_bilstm = df_usa[df_usa[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_france_bilstm = df_france[df_france[1] != 'I-ARGM-LOC'].sort_values(by=[1])

# %%
display(error_japan_bilstm[[0,'pp_descr']])

display(error_usa_bilstm[[0,'pp_descr']])

display(error_france_bilstm[[0,'pp_descr']])
# Out:
#                             0                                         pp_descr
# 0    しんいち walks in Amagasaki.           [V: しんいち] [ARG1: walks in Amagasaki] .
# 4    だいすけ walks in Yokkaichi.           [V: だいすけ] [ARG1: walks in Yokkaichi] .
# 71     あきら walks in Yokohama.     [ARG0: あきら] [V: walks] [ARG1: in Yokohama] .
# 43       だいすけ walks in Chiba.               [V: だいすけ] [ARG1: walks in Chiba] .
# 37     こういち walks in Tsukuba.             [V: こういち] [ARG1: walks in Tsukuba] .
# 29       まさお walks in Kurume.               [V: まさお] [ARG1: walks in Kurume] .
# 25        えいじ walks in Fuchū.                [V: えいじ] [ARG1: walks in Fuchū] .
# 90      ゆたか walks in Saitama.  [ARG0: ゆたか] [V: walks] [ARGM-DIR: in Saitama] .
# 99      かずや walks in Saitama.  [ARG0: かずや] [V: walks] [ARGM-DIR: in Saitama] .
# 16      まさし walks in Kashiwa.                            まさし walks in Kashiwa.
# 92         しんじ walks in Naha.                               しんじ walks in Naha.
# 84    たけお walks in Tokushima.                          たけお walks in Tokushima.
# 78    のぶお walks in Fukushima.                          のぶお walks in Fukushima.
# 74   ひろき walks in Tokorozawa.                         ひろき walks in Tokorozawa.
# 73          太郎 walks in Naha.                                太郎 walks in Naha.
# 70         ケン walks in Akita.                               ケン walks in Akita.
# 66       とおる walks in Nagoya.                             とおる walks in Nagoya.
# 6   みつお walks in Nishinomiya.                        みつお walks in Nishinomiya.
# 7      まこと walks in Yokohama.                           まこと walks in Yokohama.
# 38   よしあき walks in Tokushima.                         よしあき walks in Tokushima.
# 9   よしたか walks in Utsunomiya.                        よしたか walks in Utsunomiya.
# 33        のぶお walks in Ōsaka.                              のぶお walks in Ōsaka.
# 12       まさひこ walks in Ōsaka.                             まさひこ walks in Ōsaka.
# 51    たつお walks in Fukushima.                          たつお walks in Fukushima.
# 98    まさのり walks in Kawasaki.                          まさのり walks in Kawasaki.
# 81        のぼる walks in Iwaki.                              のぼる walks in Iwaki.
# 85    まさし walks in Kurashiki.                          まさし walks in Kurashiki.
# 23    かずお walks in Matsumoto.                          かずお walks in Matsumoto.
# 72      まこと walks in Sapporo.                            まこと walks in Sapporo.
# 1          としお walks in Mito.                               としお walks in Mito.
# 50      まさのり walks in Nagano.                            まさのり walks in Nagano.
# 94        まさひこ walks in Ōtsu.                              まさひこ walks in Ōtsu.
# 59   こうじ walks in Kitakyūshū.                         こうじ walks in Kitakyūshū.
# 46   みつお walks in Kitakyūshū.                         みつお walks in Kitakyūshū.
#                                     0  \
# 2          Daniel walks in Anchorage.
# 61          Bob walks in Albuquerque.
# 0     Samuel walks in Virginia Beach.
# 65      Matthew walks in Baton Rouge.
# 72              Aaron walks in Tulsa.
# 74              Gary walks in Fresno.
# 75            Billy walks in Chicago.
# 76       Jeff walks in New York City.
# 78    Tony walks in Colorado Springs.
# 79           Albert walks in Lincoln.
# 80        Nick walks in Jacksonville.
# 84         Alan walks in Chula Vista.
# 87      Rick walks in Corpus Christi.
# 90             Jimmy walks in Newark.
# 93          Tony walks in Greensboro.
# 94      Greg walks in Virginia Beach.
# 59        Harry walks in Los Angeles.
# 56             Bruce walks in Tucson.
# 49  Aaron walks in Lexington-Fayette.
# 41       Brian walks in Philadelphia.
# 39             Alan walks in Raleigh.
# 4           Ken walks in Baton Rouge.
# 30             Steve walks in Laredo.
# 28        Jerry walks in New Orleans.
# 5     Alexander walks in Jersey City.
# 23     Arthur walks in New York City.
# 95          Jeff walks in Long Beach.
# 21    Arthur walks in Virginia Beach.
# 11        Ken walks in Oklahoma City.
# 9             Donald walks in Durham.
# 46              Mark walks in Laredo.
# 31     Adam walks in Honolulu County.
# 12             Harold walks in Tulsa.
# 88          Kenneth walks in Phoenix.
# 22             Eugene walks in Tulsa.
# 38           Edward walks in Orlando.
# 27    Steve walks in Honolulu County.
# 97                Fred walks in Mesa.
#
#                                              pp_descr
# 2    [ARG0: Daniel] [V: walks] in [ARG1: Anchorage] .
# 61  [ARG0: Bob] [V: walks] [ARG1: in] [ARG1: Albuq...
# 0   [ARG0: Samuel] [V: walks] [ARG1: in Virginia B...
# 65  [ARG0: Matthew] [V: walks] [ARG1: in Baton Rou...
# 72        [ARG0: Aaron] [V: walks] [ARG1: in Tulsa] .
# 74        [ARG0: Gary] [V: walks] [ARG1: in Fresno] .
# 75      [ARG0: Billy] [V: walks] [ARG1: in Chicago] .
# 76  [ARG0: Jeff] [V: walks] [ARG1: in New York Cit...
# 78  [ARG0: Tony] [V: walks] [ARG1: in Colorado Spr...
# 79     [ARG0: Albert] [V: walks] [ARG1: in Lincoln] .
# 80  [ARG0: Nick] [V: walks] [ARG1: in Jacksonville] .
# 84   [ARG0: Alan] [V: walks] [ARG1: in Chula Vista] .
# 87  [ARG0: Rick] [V: walks] [ARG1: in Corpus Chris...
# 90       [ARG0: Jimmy] [V: walks] [ARG1: in Newark] .
# 93    [ARG0: Tony] [V: walks] [ARG1: in Greensboro] .
# 94  [ARG0: Greg] [V: walks] [ARG1: in Virginia Bea...
# 59  [ARG0: Harry] [V: walks] [ARG1: in Los Angeles] .
# 56       [ARG0: Bruce] [V: walks] [ARG1: in Tucson] .
# 49  [ARG0: Aaron] [V: walks] [ARG1: in Lexington -...
# 41  [ARG0: Brian] [V: walks] [ARG1: in Philadelphi...
# 39       [ARG0: Alan] [V: walks] [ARG1: in Raleigh] .
# 4     [ARG0: Ken] [V: walks] [ARG1: in Baton Rouge] .
# 30       [ARG0: Steve] [V: walks] [ARG1: in Laredo] .
# 28  [ARG0: Jerry] [V: walks] [ARG1: in New Orleans] .
# 5   [ARG0: Alexander] [V: walks] [ARG1: in Jersey ...
# 23  [ARG0: Arthur] [V: walks] [ARG1: in New York C...
# 95    [ARG0: Jeff] [V: walks] [ARG1: in Long Beach] .
# 21  [ARG0: Arthur] [V: walks] [ARG1: in Virginia B...
# 11  [ARG0: Ken] [V: walks] [ARG1: in Oklahoma City] .
# 9       [ARG0: Donald] [V: walks] [ARG1: in Durham] .
# 46    [ARG0: Mark] [V: walks] [ARGM-DIR: in Laredo] .
# 31  [ARG0: Adam] [V: walks] [ARGM-DIR: in Honolulu...
# 12   [ARG0: Harold] [V: walks] [ARGM-DIR: in Tulsa] .
# 88  [ARG0: Kenneth] [V: walks] [ARGM-DIR: in Phoen...
# 22   [ARG0: Eugene] [V: walks] [ARGM-MNR: in Tulsa] .
# 38  [ARG0: Edward] [V: walks] [ARGM-MNR: in Orland...
# 27  [ARG0: Steve] [V: walks] [ARGM-MNR: in Honolul...
# 97                                Fred walks in Mesa.
#                                          0  \
# 51                Thierry walks in Cannes.
# 46                  Jules walks in Cannes.
# 98                 Jules walks in Avignon.
# 52              Thierry walks in Poitiers.
# 58                Alfred walks in Roubaix.
# 26          David walks in Fort-de-France.
# 65                Charles walks in Angers.
# 24          Albert walks in Aubervilliers.
# 79       Jean-Pierre walks in La Rochelle.
# 2              Jean walks in Saint-Pierre.
# 43       Jean-Marie walks in Saint-Pierre.
# 77                     Marie walks in Pau.
# 44            Jérôme walks in La Rochelle.
# 64              Jérôme walks in Le Tampon.
# 90                     Henry walks in Pau.
# 56                 Marie walks in Avignon.
# 92           Patrice walks in La Rochelle.
# 97                   Marc walks in Cholet.
# 74                Marie walks in Chambéry.
# 0                Pierre walks in Poitiers.
# 99           Christophe walks in Le Havre.
# 40                    Claude walks in Pau.
# 1           Jean-Marie walks in Tourcoing.
# 36                  Paul walks in Avignon.
# 32      Jean-Marie walks in Aubervilliers.
# 10            Emmanuel walks in Le Tampon.
# 96   Jean-Michel walks in Vitry-sur-Seine.
# 94        Lucien walks in Vitry-sur-Seine.
# 4     Marcel walks in Champigny-sur-Marne.
# 85  Dominique walks in Asnières-sur-Seine.
# 84        Alfred walks in Rueil-Malmaison.
# 81       Christian walks in Aubervilliers.
# 6       Jacques walks in Aulnay-sous-Bois.
# 78     Marcel walks in Asnières-sur-Seine.
# 9               Michel walks in Le Tampon.
# 70       Gabriel walks in Rueil-Malmaison.
# 41      Marie walks in Asnières-sur-Seine.
# 50     Sébastien walks in Vitry-sur-Seine.
# 45     Joseph walks in Asnières-sur-Seine.
# 39              Bernard walks in Nanterre.
# 47    Sébastien walks in Aulnay-sous-Bois.
# 49       Raymond walks in Vitry-sur-Seine.
# 67     Gérard walks in Asnières-sur-Seine.
# 69         Denis walks in Vitry-sur-Seine.
# 57          Paul walks in Vitry-sur-Seine.
# 12         Jean-Claude walks in Le Tampon.
# 53    Vincent walks in Asnières-sur-Seine.
# 86    Jean-Louis walks in Vitry-sur-Seine.
# 88       Jean-Louis walks in Saint-Pierre.
# 3       André walks in Asnières-sur-Seine.
# 62    Jean-Louis walks in Rueil-Malmaison.
# 82                Émile walks in Colombes.
# 34                   Alain walks in Paris.
# 33           Alain walks in Aubervilliers.
# 42         Jean-Baptiste walks in Antibes.
# 29                 Émile walks in Roubaix.
#
#                                              pp_descr
# 51     [ARG0: Thierry] [V: walks] [ARG1: in Cannes] .
# 46       [ARG0: Jules] [V: walks] [ARG1: in Cannes] .
# 98      [ARG0: Jules] [V: walks] [ARG1: in Avignon] .
# 52   [ARG0: Thierry] [V: walks] [ARG1: in Poitiers] .
# 58     [ARG0: Alfred] [V: walks] [ARG1: in Roubaix] .
# 26  [ARG0: David] [V: walks] [ARG1: in Fort - de -...
# 65     [ARG0: Charles] [V: walks] [ARG1: in Angers] .
# 24  [ARG0: Albert] [V: walks] [ARG1: in Aubervilli...
# 79  [ARG0: Jean - Pierre] [V: walks] [ARG1: in La ...
# 2   [ARG0: Jean] [V: walks] [ARG1: in Saint - Pier...
# 43  [ARG0: Jean - Marie] [V: walks] [ARGM-DIR: in]...
# 77      [ARG0: Marie] [V: walks] [ARGM-DIR: in Pau] .
# 44  [ARG0: Jérôme] [V: walks] [ARGM-DIR: in La Roc...
# 64  [ARG0: Jérôme] [V: walks] [ARGM-DIR: in Le Tam...
# 90      [ARG0: Henry] [V: walks] [ARGM-DIR: in Pau] .
# 56  [ARG0: Marie] [V: walks] [ARGM-DIR: in Avignon] .
# 92  [ARG0: Patrice] [V: walks] [ARGM-DIR: in La Ro...
# 97    [ARG0: Marc] [V: walks] [ARGM-DIR: in Cholet] .
# 74  [ARG0: Marie] [V: walks] [ARGM-DIR: in Chambér...
# 0   [ARG0: Pierre] [V: walks] [ARGM-DIR: in Poitie...
# 99  [ARG0: Christophe] [V: walks] [ARGM-DIR: in Le...
# 40     [ARG0: Claude] [V: walks] [ARGM-DIR: in Pau] .
# 1   [ARG0: Jean - Marie] [V: walks] [ARGM-DIR: in ...
# 36   [ARG0: Paul] [V: walks] [ARGM-DIR: in Avignon] .
# 32  [ARG0: Jean - Marie] [V: walks] [ARGM-DIR: in ...
# 10  [ARG0: Emmanuel] [V: walks] [ARGM-DIR: in Le T...
# 96  [ARG0: Jean - Michel] [V: walks] [ARGM-MNR: in...
# 94  [ARG0: Lucien] [V: walks] [ARGM-MNR: in Vitry ...
# 4   [ARG0: Marcel] [V: walks] [ARGM-MNR: in Champi...
# 85  [ARG0: Dominique] [V: walks] [ARGM-MNR: in Asn...
# 84  [ARG0: Alfred] [V: walks] [ARGM-MNR: in Rueil ...
# 81  [ARG0: Christian] [V: walks] [ARGM-MNR: in Aub...
# 6   [ARG0: Jacques] [V: walks] [ARGM-MNR: in Aulna...
# 78  [ARG0: Marcel] [V: walks] [ARGM-MNR: in Asnièr...
# 9   [ARG0: Michel] [V: walks] [ARGM-MNR: in Le Tam...
# 70  [ARG0: Gabriel] [V: walks] [ARGM-MNR: in Rueil...
# 41  [ARG0: Marie] [V: walks] [ARGM-MNR: in Asnière...
# 50  [ARG0: Sébastien] [V: walks] [ARGM-MNR: in Vit...
# 45  [ARG0: Joseph] [V: walks] [ARGM-MNR: in Asnièr...
# 39  [ARG0: Bernard] [V: walks] [ARGM-MNR: in Nante...
# 47  [ARG0: Sébastien] [V: walks] [ARGM-MNR: in Aul...
# 49  [ARG0: Raymond] [V: walks] [ARGM-MNR: in Vitry...
# 67  [ARG0: Gérard] [V: walks] [ARGM-MNR: in Asnièr...
# 69  [ARG0: Denis] [V: walks] [ARGM-MNR: in Vitry -...
# 57  [ARG0: Paul] [V: walks] [ARGM-MNR: in Vitry - ...
# 12  [ARG0: Jean - Claude] [V: walks] [ARGM-MNR: in...
# 53  [ARG0: Vincent] [V: walks] [ARGM-MNR: in Asniè...
# 86               Jean-Louis walks in Vitry-sur-Seine.
# 88                  Jean-Louis walks in Saint-Pierre.
# 3                  André walks in Asnières-sur-Seine.
# 62               Jean-Louis walks in Rueil-Malmaison.
# 82                           Émile walks in Colombes.
# 34                              Alain walks in Paris.
# 33                      Alain walks in Aubervilliers.
# 42                    Jean-Baptiste walks in Antibes.
# 29                            Émile walks in Roubaix.

# %%
error_rate_france_bilstm = len(df_france[df_france[1]!='I-ARGM-LOC'])/len(df_france)*100
error_rate_japan_bilstm = len(df_japan[df_japan[1]!='I-ARGM-LOC'])/len(df_japan)*100
error_rate_usa_bilstm = len(df_usa[df_usa[1]!='I-ARGM-LOC'])/len(df_usa)*100

# %%
print("BERT ERROR RATE")
print("france: " , error_rate_france_bert)
print("japan: " , error_rate_japan_bert)
print("usa: " , error_rate_usa_bert)
print()
print("bilstm ERROR RATE")
print("france: " , error_rate_france_bilstm)
print("japan: " , error_rate_japan_bilstm)
print("usa: " , error_rate_usa_bilstm)
# Out:
# BERT ERROR RATE
# france:  24.0
# japan:  42.0
# usa:  6.0
#
# bilstm ERROR RATE
# france:  56.00000000000001
# japan:  34.0
# usa:  38.0
