# %%
from allennlp_models.pretrained import load_predictor
from allennlp_models.pretrained import get_pretrained_models

import checklist
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect

from checklist.pred_wrapper import PredictorWrapper
import pandas as pd

from nltk.corpus import wordnet as wn
import random

# %%
nsamples = 1

# %%
def switch_topic(sentence):#, split):
    string_split = sentence.split()
    topic = string_split[-2:]
    topic[0] = topic[0].capitalize()
    topic = words = [w.replace(".", ",") for w in topic]
    not_topic = string_split[:-2]
    if not_topic[0] != "I":
        not_topic[0] = not_topic[0].lower()
    rebuilt_sentence_list = topic + not_topic
    rebuilt_sentence = " ".join(rebuilt_sentence_list)+"."
    return rebuilt_sentence

def get_pp_tags(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_tags = output['verbs'][1]['tags']#['verb']#[0]['tags']
    else:
        pp_tags = []
    return pp_tags

def get_pp_descr(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_descr = output['verbs'][1]['description']
    else:
        pp_descr = []
    return pp_descr

def find_final_min_one_arg(list_of_arg):
    if list_of_arg:
        element = list_of_arg[-3]
    else:
        element = 'missed_verb'
    return element

def find_first_arg(list_of_arg):
    if list_of_arg:
        element = list_of_arg[0]
    else:
        element = 'missed_verb'
    return element

def get_loc_tags(sentence):
    output = srl_predictor.predict(sentence)
    loc_tags = output['verbs'][1]['tags'][-2]
    return loc_tags

# %%
food = wn.synset('food.n.02')
food = list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))
singular_food =  [x.lower() for x in food if "_" not in x ]

# random.seed(18)
# sampled_list = random.sample(singular_food, 100)
# print(sampled_list)

# %%
list_topicalization = []
editor = Editor()

test_data = editor.template("I wont eat that {singular_food}.",
                            singular_food = singular_food,
                            meta=True, 
                            seed=42,  
                            nsamples=nsamples,
                            remove_duplicates=True)
list_topicalization.append(test_data['data'])

#flatten list
list_topicalization = [x for xs in list_topicalization for x in xs]

# %%
df = pd.DataFrame(list_topicalization)
df[1] = df[0].apply(switch_topic)
df.rename(columns = {0:'original', 1:'switched'}, inplace = True)

df['tags_original'] = df['original'].apply(get_pp_tags)
df['descr_original'] = df['original'].apply(get_pp_descr)

df['tags_switched'] = df['switched'].apply(get_pp_tags)
df['descr_switched'] = df['switched'].apply(get_pp_descr)

df['final-1_arg_original'] = df['tags_original'].apply(find_final_min_one_arg)
df['first_arg_switch'] = df['tags_switched'].apply(find_first_arg)

df['first_arg_switch'] = df['first_arg_switch'].str.replace('B-', '')
df['first_arg_switch'] = df['first_arg_switch'].str.replace('I-', '')

df['final-1_arg_original'] = df['final-1_arg_original'].str.replace('I-', '')
df['final-1_arg_original'] = df['final-1_arg_original'].str.replace('B-', '')

df['orginal_switched_match'] = df['final-1_arg_original'] != df['first_arg_switch']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8v/s7d6dz912f93j_c9dwn7szt80000gn/T/ipykernel_57474/3439298433.py in <module>
#       3 df.rename(columns = {0:'original', 1:'switched'}, inplace = True)
#       4
# ----> 5 df['tags_original'] = df['original'].apply(get_pp_tags)
#       6 df['descr_original'] = df['original'].apply(get_pp_descr)
#       7
#
# ~/opt/anaconda3/envs/the/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/opt/anaconda3/envs/the/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/opt/anaconda3/envs/the/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/opt/anaconda3/envs/the/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/8v/s7d6dz912f93j_c9dwn7szt80000gn/T/ipykernel_57474/1882341622.py in get_pp_tags(sentence)
#      12
#      13 def get_pp_tags(sentence):
# ---> 14     output = srl_predictor.predict(sentence)
#      15     if len(output['verbs']) >= 1:
#      16         pp_tags = output['verbs'][1]['tags']#['verb']#[0]['tags']
#
# NameError: name 'srl_predictor' is not defined

# %%
pd.set_option('max_colwidth', 400)
df[df['orginal_switched_match'] == False][['descr_original', 'descr_switched']]
# Out:
#                                                                 descr_original  \
# 9        [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that chard] .
# 17      [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that macoun] .
# 19      [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that grouse] .
# 22      [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that endive] .
# 37         [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that dog] .
# 46        [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that snap] .
# 48  [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that periwinkle] .
# 58     [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that twinkie] .
# 70    [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that rollmops] .
# 77        [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that loin] .
# 84     [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that crumpet] .
# 91      [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that banger] .
# 93    [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that sparling] .
# 95      [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] [ARG1: that casaba] .
#
#                                                                       descr_switched
# 9        [ARGM-DIS: That chard] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 17      [ARGM-DIS: That macoun] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 19                  That grouse , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 22      [ARGM-DIS: That endive] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 37         [ARGM-DIS: That dog] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 46                                                    That snap , I [V: wo] nt eat .
# 48  [ARGM-PRD: That periwinkle] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 58     [ARGM-DIS: That twinkie] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 70                                                That rollmops , I [V: wo] nt eat .
# 77        [ARGM-PRD: That loin] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 84     [ARGM-ADV: That crumpet] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 91      [ARGM-DIS: That banger] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 93    [ARGM-ADV: That sparling] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .
# 95      [ARGM-ADV: That casaba] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: nt] [V: eat] .

# %%
df[df['orginal_switched_match'] == False].first_arg_switch.value_counts()
# Out:
# ARGM-DIS    6
# O           3
# ARGM-ADV    3
# ARGM-PRD    2
# Name: first_arg_switch, dtype: int64

# %%
srl_predictor = load_predictor('structured-prediction-srl-bert')
# Out:
# lerc is not a registered model.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
food = wn.synset('food.n.02')
food = list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))
singular_food =  [x.lower() for x in food if "_" not in x ]

# random.seed(18)
# sampled_list = random.sample(singular_food, 100)
# print(sampled_list)
# Out:
# /Users/syb/opt/anaconda3/envs/the/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:579: UserWarning: Discarded redundant search for Synset('lunch_meat.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/syb/opt/anaconda3/envs/the/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:579: UserWarning: Discarded redundant search for Synset('headcheese.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/syb/opt/anaconda3/envs/the/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:579: UserWarning: Discarded redundant search for Synset('haslet.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/syb/opt/anaconda3/envs/the/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:579: UserWarning: Discarded redundant search for Synset('leg_of_lamb.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/syb/opt/anaconda3/envs/the/lib/python3.9/site-packages/nltk/corpus/reader/wordnet.py:579: UserWarning: Discarded redundant search for Synset('rack_of_lamb.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):

# %%
list_topicalization = []

editor = Editor()
test_data = editor.template("I will eat that {singular_food}.",
                            singular_food = singular_food,
                            meta=True, 
                            seed=42,  
                            nsamples=100,
                            remove_duplicates=True)
list_topicalization.append(test_data['data'])

#flatten list
list_topicalization = [x for xs in list_topicalization for x in xs]

# %%
df = pd.DataFrame(list_topicalization)
df[1] = df[0].apply(switch_topic)
df.rename(columns = {0:'original', 1:'switched'}, inplace = True)

df['tags_original'] = df['original'].apply(get_pp_tags)
df['descr_original'] = df['original'].apply(get_pp_descr)

df['tags_switched'] = df['switched'].apply(get_pp_tags)
df['descr_switched'] = df['switched'].apply(get_pp_descr)

df['final-1_arg_original'] = df['tags_original'].apply(find_final_min_one_arg)
df['first_arg_switch'] = df['tags_switched'].apply(find_first_arg)

df['first_arg_switch'] = df['first_arg_switch'].str.replace('B-', '')
df['first_arg_switch'] = df['first_arg_switch'].str.replace('I-', '')

df['final-1_arg_original'] = df['final-1_arg_original'].str.replace('I-', '')
df['final-1_arg_original'] = df['final-1_arg_original'].str.replace('B-', '')

df['orginal_switched_match'] = df['final-1_arg_original'] == df['first_arg_switch']

# %%
df.head(5)
# Out:
#                      original                     switched  \
# 0    I will eat that popover.    That popover, I will eat.
# 1      I will eat that cisco.      That cisco, I will eat.
# 2   I will eat that pheasant.   That pheasant, I will eat.
# 3    I will eat that sultana.    That sultana, I will eat.
# 4  I will eat that shellfish.  That shellfish, I will eat.
#
#                                   tags_original  \
# 0  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 1  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 2  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 3  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 4  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
#
#                                                  descr_original  \
# 0    [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that popover] .
# 1      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that cisco] .
# 2   [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that pheasant] .
# 3    [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that sultana] .
# 4  [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that shellfish] .
#
#                                              tags_switched  \
# 0          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 1  [B-ARGM-DIS, I-ARGM-DIS, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 2          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 3  [B-ARGM-DIS, I-ARGM-DIS, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 4          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
#
#                                                      descr_switched  \
# 0      [ARG1: That popover] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 1    [ARGM-DIS: That cisco] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 2     [ARG1: That pheasant] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 3  [ARGM-DIS: That sultana] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 4    [ARG1: That shellfish] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
#
#   final-1_arg_original first_arg_switch  orginal_switched_match
# 0                 ARG1             ARG1                    True
# 1                 ARG1         ARGM-DIS                   False
# 2                 ARG1             ARG1                    True
# 3                 ARG1         ARGM-DIS                   False
# 4                 ARG1             ARG1                    True

# %%
# !jt -t chesterish
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# install jupyterthemes
# !pip install jupyterthemes

# upgrade to latest version
# !pip install --upgrade jupyterthemes
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#      |█████                           | 1.1 MB 127 kB/s eta 0:00:47ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/http/client.py", line 462, in read
#     n = self.readinto(b)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/http/client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/commands/install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 472, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 341, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 140, in __bool__
#     return any(self)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 128, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 32, in _iter_built
#     candidate = func()
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 295, in __init__
#     super().__init__(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/network/download.py", line 145, in __call__
#     for chunk in chunks:
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/progress_bars.py", line 144, in iter
#     for x in it:
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/syb/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 99 kB/s eta 0:00:013     |████████████████████████        | 5.3 MB 22 kB/s eta 0:01:20
# Requirement already satisfied: notebook>=5.6.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jupyterthemes) (6.4.5)
# Requirement already satisfied: matplotlib>=1.4.3 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jupyterthemes) (3.4.3)
# Collecting lesscpy>=0.11.2
#   Downloading lesscpy-0.15.0-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.4.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jupyterthemes) (7.29.0)
# Requirement already satisfied: jupyter-core in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jupyterthemes) (4.8.1)
# Requirement already satisfied: pexpect>4.3 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.0)
# Requirement already satisfied: decorator in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.0)
# Requirement already satisfied: backcall in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: pygments in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (58.0.4)
# Requirement already satisfied: pickleshare in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.0)
# Requirement already satisfied: appnope in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.2)
# Requirement already satisfied: six in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from lesscpy>=0.11.2->jupyterthemes) (1.16.0)
# Requirement already satisfied: ply in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: cycler>=0.10 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.3.1)
# Requirement already satisfied: ipython-genutils in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (5.1.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (0.9.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: tornado>=6.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: pyzmq>=17 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (22.2.1)
# Requirement already satisfied: ipykernel in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (0.11.0)
# Requirement already satisfied: nbconvert in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1.0)
# Requirement already satisfied: argon2-cffi in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (20.1.0)
# Requirement already satisfied: jinja2 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from notebook>=5.6.0->jupyterthemes) (2.11.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.4.1->jupyterthemes) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.14.6)
# Requirement already satisfied: pycparser in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.20)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (1.1.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: bleach in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.4.3)
# Requirement already satisfied: testpath in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.3)
# Requirement already satisfied: nest-asyncio in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: async-generator in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.6.0->jupyterthemes) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: webencodings in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: packaging in /Users/syb/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (21.0)
# Installing collected packages: lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.0

# %%
df.orginal_switched_match.value_counts()
# Out:
# True     93
# False     7
# Name: orginal_switched_match, dtype: int64

# %%
df[df['orginal_switched_match'] == False].first_arg_switch.value_counts()
# Out:
# ARGM-DIS    6
# O           1
# Name: first_arg_switch, dtype: int64

# %%
pd.set_option('max_colwidth', 400)
df[df['orginal_switched_match'] == False][['descr_original', 'descr_switched']]
# Out:
#                                                  descr_original  \
# 1      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that cisco] .
# 3    [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that sultana] .
# 15      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that snap] .
# 50       [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that roe] .
# 54    [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that confit] .
# 74   [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that grouper] .
# 94  [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that bartlett] .
#
#                                                               descr_switched
# 1             [ARGM-DIS: That cisco] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 3           [ARGM-DIS: That sultana] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 15                                             That snap , I [V: will] eat .
# 50  [ARGM-DIS: That] [ARGM-DIS: roe] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 54           [ARGM-DIS: That confit] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 74          [ARGM-DIS: That grouper] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 94         [ARGM-DIS: That bartlett] , [ARG0: I] [ARGM-MOD: will] [V: eat] .

# %%
df
# Out:
#                        original                      switched  \
# 0      I will eat that popover.     That popover, I will eat.
# 1        I will eat that cisco.       That cisco, I will eat.
# 2     I will eat that pheasant.    That pheasant, I will eat.
# 3      I will eat that sultana.     That sultana, I will eat.
# 4    I will eat that shellfish.   That shellfish, I will eat.
# ..                          ...                           ...
# 95     I will eat that hotcake.     That hotcake, I will eat.
# 96   I will eat that sprinkles.   That sprinkles, I will eat.
# 97  I will eat that battercake.  That battercake, I will eat.
# 98      I will eat that mouton.      That mouton, I will eat.
# 99        I will eat that ghee.        That ghee, I will eat.
#
#                                    tags_original  \
# 0   [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 1   [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 2   [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 3   [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 4   [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# ..                                           ...
# 95  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 96  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 97  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 98  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
# 99  [B-ARG0, B-ARGM-MOD, B-V, B-ARG1, I-ARG1, O]
#
#                                                    descr_original  \
# 0      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that popover] .
# 1        [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that cisco] .
# 2     [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that pheasant] .
# 3      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that sultana] .
# 4    [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that shellfish] .
# ..                                                            ...
# 95     [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that hotcake] .
# 96   [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that sprinkles] .
# 97  [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that battercake] .
# 98      [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that mouton] .
# 99        [ARG0: I] [ARGM-MOD: will] [V: eat] [ARG1: that ghee] .
#
#                                               tags_switched  \
# 0           [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 1   [B-ARGM-DIS, I-ARGM-DIS, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 2           [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 3   [B-ARGM-DIS, I-ARGM-DIS, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 4           [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# ..                                                      ...
# 95          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 96          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 97          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 98          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
# 99          [B-ARG1, I-ARG1, O, B-ARG0, B-ARGM-MOD, B-V, O]
#
#                                                       descr_switched  \
# 0       [ARG1: That popover] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 1     [ARGM-DIS: That cisco] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 2      [ARG1: That pheasant] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 3   [ARGM-DIS: That sultana] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 4     [ARG1: That shellfish] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# ..                                                               ...
# 95      [ARG1: That hotcake] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 96    [ARG1: That sprinkles] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 97   [ARG1: That battercake] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 98       [ARG1: That mouton] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
# 99         [ARG1: That ghee] , [ARG0: I] [ARGM-MOD: will] [V: eat] .
#
#    final-1_arg_original first_arg_switch  orginal_switched_match
# 0                  ARG1             ARG1                    True
# 1                  ARG1         ARGM-DIS                   False
# 2                  ARG1             ARG1                    True
# 3                  ARG1         ARGM-DIS                   False
# 4                  ARG1             ARG1                    True
# ..                  ...              ...                     ...
# 95                 ARG1             ARG1                    True
# 96                 ARG1             ARG1                    True
# 97                 ARG1             ARG1                    True
# 98                 ARG1             ARG1                    True
# 99                 ARG1             ARG1                    True
#
# [100 rows x 9 columns]

# %%
len(srl_predictor.predict("That pizza, I won't eat"))
# Out:
# 2

# %%
output1 = srl_predictor.predict("I won't eat that pizza")
output2 = srl_predictor.predict("That pizza, I won't eat")

print(output1['verbs'][len(output1)-1]['description'])
print(output2['verbs'][len(output2)-1]['description'])
print()
print(output1['verbs'][1]['description'])
print(output1['verbs'][1]['tags'])
print()
print(output2['verbs'][1]['description'])
print(output2['verbs'][1]['tags'])
print()
print(output1['verbs'][len(output2)-1]['tags'][-2:])
print(output2['verbs'][len(output2)-1]['tags'][0:2])
# Out:
# [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: n't] [V: eat] [ARG1: that pizza]
# [ARG1: That pizza] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: n't] [V: eat]
#
# [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: n't] [V: eat] [ARG1: that pizza]
# ['B-ARG0', 'B-ARGM-MOD', 'B-ARGM-NEG', 'B-V', 'B-ARG1', 'I-ARG1']
#
# [ARG1: That pizza] , [ARG0: I] [ARGM-MOD: wo] [ARGM-NEG: n't] [V: eat]
# ['B-ARG1', 'I-ARG1', 'O', 'B-ARG0', 'B-ARGM-MOD', 'B-ARGM-NEG', 'B-V']
#
# ['B-ARG1', 'I-ARG1']
# ['B-ARG1', 'I-ARG1']

# %%
output1 = srl_predictor.predict('The boys roll rocks for entertainment.')
output2 = srl_predictor.predict('For entertainment, the boys roll rocks')

print(output1['verbs'][0]['description'])
print(output2['verbs'][0]['description'])
print()
print(output1['verbs'][0]['description'])
print(output1['verbs'][0]['tags'])
print()
print(output2['verbs'][0]['description'])
print(output2['verbs'][0]['tags'])
print()
print(output1['verbs'][0]['tags'][3])
print(output2['verbs'][0]['tags'][-1])
# Out:
# [ARG0: The boys] [V: roll] [ARG1: rocks] [ARGM-PRP: for entertainment] .
# [ARGM-PRP: For entertainment] , [ARG0: the boys] [V: roll] [ARG1: rocks]
#
# [ARG0: The boys] [V: roll] [ARG1: rocks] [ARGM-PRP: for entertainment] .
# ['B-ARG0', 'I-ARG0', 'B-V', 'B-ARG1', 'B-ARGM-PRP', 'I-ARGM-PRP', 'O']
#
# [ARGM-PRP: For entertainment] , [ARG0: the boys] [V: roll] [ARG1: rocks]
# ['B-ARGM-PRP', 'I-ARGM-PRP', 'O', 'B-ARG0', 'I-ARG0', 'B-V', 'B-ARG1']
#
# B-ARG1
# B-ARG1
