# %%
#!pip install jupyter-resource-usage

# %%
import pandas as pd
import checklist
from allennlp_models.pretrained import load_predictor
from allennlp_models.pretrained import get_pretrained_models
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.pred_wrapper import PredictorWrapper

# %%
editor = Editor()

# %%
srl_predictor = load_predictor('structured-prediction-srl-bert')
#srl_predictor = load_predictor('structured-prediction-srl')
# Out:
# lerc is not a registered model.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
chinese_cities = list(editor.lexicons['country_city']['China'])
us_cities = list(editor.lexicons['country_city']['United_States'])
russian_cities = list(editor.lexicons['country_city']['Russia'])

china_names_male = editor.lexicons.male_from.China
us_names_male = editor.lexicons.male_from.United_States
russian_names_male = editor.lexicons.male_from.Russia

editor.add_lexicon("china_names_male", china_names_male, overwrite=True)
editor.add_lexicon("us_names_male", us_names_male, overwrite=True)
editor.add_lexicon("russian_names_male", russian_names_male, overwrite=True)

editor.add_lexicon("chinese_cities", chinese_cities, overwrite=True)
editor.add_lexicon("us_cities", us_cities, overwrite=True)
editor.add_lexicon("russian_cities", russian_cities, overwrite=True)

chinese_china = editor.template("{china_names_male} walks in {chinese_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)
usa_usa = editor.template("{us_names_male} walks in {us_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)
russian_russia = editor.template("{russian_names_male} walks in {russian_cities}.", meta=True, nsamples=10, remove_duplicates=True, seed=42)

# %%
henkje,drenkje,penkje = make_data_fairness(1))
len(henkje)
# Out:
#   File "/var/folders/8v/s7d6dz912f93j_c9dwn7szt80000gn/T/ipykernel_50061/2121310900.py", line 1
#     henkje,drenkje,penkje = make_data_fairness(1))
#                                                  ^
# SyntaxError: unmatched ')'

# %%
def make_data_fairness(amount_per_format):
    list_japan = []
    list_usa = []
    list_france = []
    
    editor = Editor()
    
    japanese_cities = list(editor.lexicons['country_city']['Japan'])
    us_cities = list(editor.lexicons['country_city']['United_States'])
    french_cities = list(editor.lexicons['country_city']['France'])

    japanese_names_male = editor.lexicons.male_from.Japan
    us_names_male = editor.lexicons.male_from.United_States
    french_names_male = editor.lexicons.male_from.France

    editor.add_lexicon("japanese_names_male",japanese_names_male, overwrite=True)
    editor.add_lexicon("us_names_male", us_names_male, overwrite=True)
    editor.add_lexicon("french_names_male", french_names_male, overwrite=True)

    editor.add_lexicon("japanese_cities", japanese_cities, overwrite=True)
    editor.add_lexicon("us_cities", us_cities, overwrite=True)
    editor.add_lexicon("french_cities", french_cities, overwrite=True)

    japanese_japan = editor.template("{japanese_names_male} walks in {japanese_cities}.", 
                                    meta=True, 
                                    nsamples=amount_per_format, 
                                    remove_duplicates=True, 
                                    seed=18)
    list_japan.append(japanese_japan['data'])
    list_japan = [x for xs in list_japan for x in xs]
    
    
    usa_usa = editor.template("{us_names_male} walks in {us_cities}.", 
                              meta=True, 
                              nsamples=amount_per_format, 
                              remove_duplicates=True, 
                              seed=18)
    list_usa.append(usa_usa['data'])
    list_usa = [x for xs in list_usa for x in xs]
    
    french_france = editor.template("{french_names_male} walks in {french_cities}.", 
                                     meta=True, 
                                     nsamples=amount_per_format, 
                                     remove_duplicates=True, 
                                     seed=18)
    list_france.append(french_france['data'])
    list_france = [x for xs in list_france for x in xs]
    return list_japan, list_usa, list_france

# %%
def get_pp_tags(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_tags = output['verbs'][0]['tags']#['verb']#[0]['tags']
    else:
        pp_tags = sentence
    return pp_tags

def get_pp_descr(sentence):
    output = srl_predictor.predict(sentence)
    if len(output['verbs']) >= 1:
        pp_descr = output['verbs'][0]['description']
    else:
        pp_descr = sentence
    return pp_descr

def find_final_min_one_arg(list_of_arg):
    if list_of_arg:
        element = list_of_arg[-2]
    else:
        element = 'missed_verb'
    return element

# %%
list_japan, list_usa, list_france =  make_data_fairness(100)

df_japan = pd.DataFrame(list_japan)
df_japan['pp_tag'] = df_japan[0].apply(get_pp_tags)
df_japan['pp_descr'] = df_japan[0].apply(get_pp_descr)
df_japan[1] = df_japan['pp_tag'].apply(find_final_min_one_arg)

df_usa = pd.DataFrame(list_usa)
df_usa['pp_tag'] = df_usa[0].apply(get_pp_tags)
df_usa['pp_descr'] = df_usa[0].apply(get_pp_descr)
df_usa[1] = df_usa['pp_tag'].apply(find_final_min_one_arg)

df_france = pd.DataFrame(list_france)
df_france['pp_tag'] = df_france[0].apply(get_pp_tags)
df_france['pp_descr'] = df_france[0].apply(get_pp_descr)
df_france[1] = df_france['pp_tag'].apply(find_final_min_one_arg)

# %%
error_japan = df_japan[df_japan[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_usa = df_usa[df_usa[1] != 'I-ARGM-LOC'].sort_values(by=[1])
error_france = df_france[df_france[1] != 'I-ARGM-LOC'].sort_values(by=[1])

# %%
error_france[[0,'pp_descr']]
# Out:
#                                           0  \
# 1                 Auguste walks in Antibes.
# 79                Bertrand walks in Angers.
# 76                  Pierre walks in Angers.
# 74                Gustave walks in Béziers.
# 69                 Julien walks in Béziers.
# 68                Raymond walks in Créteil.
# 62                 David walks in Chambéry.
# 58                  Alfred walks in Angers.
# 54                   Léon walks in Créteil.
# 41                Georges walks in Créteil.
# 43                 Alfred walks in Créteil.
# 35                 Gaston walks in Créteil.
# 29                 Olivier walks in Angers.
# 22                Patrice walks in Créteil.
# 16           Jean-Pierre walks in Chambéry.
# 38              Jean-Marie walks in Cholet.
# 84             Christophe walks in Béziers.
# 37          Jean-Louis walks in Courbevoie.
# 42                Édouard walks in Roubaix.
# 80            René walks in Fort-de-France.
# 55        René walks in Asnières-sur-Seine.
# 59                  Émile walks in Avignon.
# 23  Jean-Louis walks in Asnières-sur-Seine.
# 65                 Émile walks in Colombes.
# 18         Jean-Baptiste walks in Poitiers.
# 10                  Ernest walks in Cholet.
# 9            Louis walks in Fort-de-France.
#
#                                              pp_descr
# 1     [ARG0: Auguste] [V: walks] [ARG1: in Antibes] .
# 79  [ARG0: Bertrand] [V: walks] [ARGM-MNR: in Ange...
# 76  [ARG0: Pierre] [V: walks] [ARGM-MNR: in Angers] .
# 74  [ARG0: Gustave] [V: walks] [ARGM-MNR: in Bézie...
# 69  [ARG0: Julien] [V: walks] [ARGM-MNR: in Bézier...
# 68  [ARG0: Raymond] [V: walks] [ARGM-MNR: in Créte...
# 62  [ARG0: David] [V: walks] [ARGM-MNR: in Chambér...
# 58  [ARG0: Alfred] [V: walks] [ARGM-MNR: in Angers] .
# 54   [ARG0: Léon] [V: walks] [ARGM-MNR: in Créteil] .
# 41  [ARG0: Georges] [V: walks] [ARGM-MNR: in Créte...
# 43  [ARG0: Alfred] [V: walks] [ARGM-MNR: in Crétei...
# 35  [ARG0: Gaston] [V: walks] [ARGM-MNR: in Crétei...
# 29  [ARG0: Olivier] [V: walks] [ARGM-MNR: in Anger...
# 22  [ARG0: Patrice] [V: walks] [ARGM-MNR: in Créte...
# 16  [ARG0: Jean - Pierre] [V: walks] [ARGM-MNR: in...
# 38  [ARG0: Jean - Marie] [V: walks] [ARGM-MNR: in ...
# 84  [ARG0: Christophe] [V: walks] [ARGM-MNR: in Bé...
# 37                                                 []
# 42                                                 []
# 80                                                 []
# 55                                                 []
# 59                                                 []
# 23                                                 []
# 65                                                 []
# 18                                                 []
# 10                                                 []
# 9                                                  []

# %%
error_usa[[0,'pp_descr']]
# Out:
#                                0  \
# 25        Alan walks in Madison.
# 30         Joe walks in Wichita.
# 43      Alfred walks in Garland.
# 88  Fred walks in San Francisco.
#
#                                              pp_descr
# 25   [ARG0: Alan] [V: walks] [ARGM-MNR: in Madison] .
# 30    [ARG0: Joe] [V: walks] [ARGM-MNR: in Wichita] .
# 43  [ARG0: Alfred] [V: walks] [ARGM-MNR: in Garlan...
# 88                                                 []

# %%
error_japan[[0,'pp_descr']]
# Out:
#                              0  \
# 57    けんたろう walks in Kōriyama.
# 96         ゆたか walks in Suita.
# 6         かずひこ walks in Chōfu.
# 93         かずひこ walks in Sōka.
# 66         あきら walks in Kōchi.
# 69   ひろゆき walks in Ichinomiya.
# 84     ひろゆき walks in Hachiōji.
# 25        けんいち walks in Suita.
# 64     だいすけ walks in Nagasaki.
# 65   しんいち walks in Utsunomiya.
# 76           えいじ walks in Tsu.
# 48       まさお walks in Saitama.
# 80    しんいち walks in Funabashi.
# 92      やすお walks in Yokosuka.
# 44        やすお walks in Kurume.
# 75     ふみお walks in Kurashiki.
# 72      まこと walks in Hirakata.
# 70       しんじ walks in Sapporo.
# 85      ゆうすけ walks in Morioka.
# 89         たつお walks in Suita.
# 91       のぼる walks in Okayama.
# 78     ひろき walks in Funabashi.
# 0      ひとし walks in Funabashi.
# 98     よしたか walks in Kakogawa.
# 2          まさひこ walks in Fuji.
# 7       よしあき walks in Niigata.
# 9          まさし walks in Chiba.
# 10     きよし walks in Hiratsuka.
# 15  たつお walks in Higashiōsaka.
# 17      かずお walks in Hachiōji.
# 20       かずお walks in Tsukuba.
# 21       いさお walks in Morioka.
# 24     のぶお walks in Koshigaya.
# 27          しげる walks in Ōtsu.
# 29     じゅんいち walks in Niigata.
# 31     みつお walks in Hiratsuka.
# 34     まさし walks in Yokkaichi.
# 38     のぶお walks in Kagoshima.
# 40          ひとし walks in Gifu.
# 41    じゅんいち walks in Wakayama.
# 42    まさゆき walks in Funabashi.
# 49    よしあき walks in Fukushima.
# 99      じゅんいち walks in Himeji.
#
#                                              pp_descr
# 57  [ARG0: けんたろう] [V: walks] [ARGM-MNR: in Kōriyam...
# 96      [ARG0: ゆたか] [V: walks] [ARGM-MNR: in Suita] .
# 6      [ARG0: かずひこ] [V: walks] [ARGM-MNR: in Chōfu] .
# 93      [ARG0: かずひこ] [V: walks] [ARGM-MNR: in Sōka] .
# 66      [ARG0: あきら] [V: walks] [ARGM-MNR: in Kōchi] .
# 69  [ARG0: ひろゆき] [V: walks] [ARGM-MNR: in Ichinomi...
# 84  [ARG0: ひろゆき] [V: walks] [ARGM-MNR: in Hachiōji] .
# 25     [ARG0: けんいち] [V: walks] [ARGM-MNR: in Suita] .
# 64                      [V: だいすけ] walks in Nagasaki .
# 65                    [V: しんいち] walks in Utsunomiya .
# 76                            [V: えいじ] walks in Tsu .
# 48                        [V: まさお] walks in Saitama .
# 80                     [V: しんいち] walks in Funabashi .
# 92                       [V: やすお] walks in Yokosuka .
# 44                         [V: やすお] walks in Kurume .
# 75                                                 []
# 72                                                 []
# 70                                                 []
# 85                                                 []
# 89                                                 []
# 91                                                 []
# 78                                                 []
# 0                                                  []
# 98                                                 []
# 2                                                  []
# 7                                                  []
# 9                                                  []
# 10                                                 []
# 15                                                 []
# 17                                                 []
# 20                                                 []
# 21                                                 []
# 24                                                 []
# 27                                                 []
# 29                                                 []
# 31                                                 []
# 34                                                 []
# 38                                                 []
# 40                                                 []
# 41                                                 []
# 42                                                 []
# 49                                                 []
# 99                                                 []

# %%
print(len(df_france[df_france[1]!='I-ARGM-LOC'])/len(df_france)*100)
print(len(df_japan[df_japan[1]!='I-ARGM-LOC'])/len(df_japan)*100)
print(len(df_usa[df_usa[1]!='I-ARGM-LOC'])/len(df_usa)*100)
# Out:
# 27.0
# 43.0
# 4.0
