# %%
from allennlp_models.pretrained import load_predictor
from allennlp_models.pretrained import get_pretrained_models

import checklist
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect

from checklist.pred_wrapper import PredictorWrapper

# %%
## list taken from: https://media.bloomsbury.com/rep/files/chapter-1-project-1-5_a-list_of_inanimate_objects.pdf

string_objects = '''
sofa
coffee table
dresser
wooden chair
plush chair
rolling office chair
footstool
kitchen table
toilet
bathtub
bathroom sink
ornate mirror
stove
refrigerator
soap dispenser
tape dispenser
stapler
toothbrush
toothpaste
umbrella
shoe
hammer
pliers
iron
spray bottle
baby bottle
toothbrush
toothpaste
clothespin
teapot
teacup
coffeepot
coffee mug
orange juice box
milk jug
spoon
fork
knife
power outlet
book
briefcase
telephone
desk lamp
standing lamp'''
list_objects = string_objects.split('\n')
list_objects.remove(list_objects[0])

# %%
def make_data_pp_attachment(amount_per_format):
    list_pp_attachment = []

    editor = Editor()
    test_data = editor.template("I saw the {list_objects} with my eyes.",
                                list_objects = list_objects,
                                meta=True, seed=42,  
                                nsamples=amount_per_format,
                                remove_duplicates=True)
    list_pp_attachment.append(test_data['data'])

    test_data = editor.template("I smelled the {list_objects} with my nose.", 
                                list_objects = list_objects,
                                meta=True, seed=42,  
                                nsamples=amount_per_format,
                                remove_duplicates=True)
    list_pp_attachment.append(test_data['data'])

    test_data = editor.template("I heard the {list_objects} with my ears.",
                                list_objects = list_objects,
                                meta=True, seed=42,  
                                nsamples=amount_per_format,
                                remove_duplicates=True)
    list_pp_attachment.append(test_data['data'])

    test_data = editor.template("I tasted the {list_objects} with my tongue.", 
                                list_objects = list_objects,
                                meta=True, seed=42,  
                                nsamples=amount_per_format,
                                remove_duplicates=True)
    list_pp_attachment.append(test_data['data'])
    list_pp_attachment = [x for xs in list_pp_attachment for x in xs]
    return list_pp_attachment

# %%
list_pp_attachment = make_data_pp_attachment(45)
df_pp = pd.DataFrame(list_pp_attachment)

df.pp[0].to_csv("../datasets/pp_attchment/japan.txt", header=None, index=False)

# %%
def get_pp_tags(sentence):
    output = srl_predictor.predict(sentence)
    pp_tags = output['verbs'][0]['tags']
    return pp_tags

def get_pp_descr(sentence):
    output = srl_predictor.predict(sentence)
    pp_descr = output['verbs'][0]['description']
    return pp_descr

def find_final_min_one_arg(list_of_arg):
    return list_of_arg[-2]

df_pp['pp_tag'] = df_pp[0].apply(get_pp_tags)
df_pp['pp_descr'] = df_pp[0].apply(get_pp_descr)
df_pp[1] = df_pp['pp_tag'].apply(find_final_min_one_arg)

df_pp.drop_duplicates(subset=[0],inplace=True)
df_pp[1].value_counts()
# Out:
# I-ARGM-MNR    141
# I-ARG1         20
# I-ARG2         19
# Name: 1, dtype: int64

# %%
pd.set_option('max_colwidth', 400)
df_pp.head(5)
# Out:
#                                     0  \
# 0      I saw the teapot with my eyes.
# 1        I saw the fork with my eyes.
# 2     I saw the stapler with my eyes.
# 3  I saw the toothpaste with my eyes.
# 4      I saw the toilet with my eyes.
#
#                                                                  pp_tag  \
# 0  [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARGM-MNR, I-ARGM-MNR, I-ARGM-MNR, O]
# 1  [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARGM-MNR, I-ARGM-MNR, I-ARGM-MNR, O]
# 2  [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARGM-MNR, I-ARGM-MNR, I-ARGM-MNR, O]
# 3  [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARGM-MNR, I-ARGM-MNR, I-ARGM-MNR, O]
# 4  [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARGM-MNR, I-ARGM-MNR, I-ARGM-MNR, O]
#
#                                                                pp_descr  \
# 0      [ARG0: I] [V: saw] [ARG1: the teapot] [ARGM-MNR: with my eyes] .
# 1        [ARG0: I] [V: saw] [ARG1: the fork] [ARGM-MNR: with my eyes] .
# 2     [ARG0: I] [V: saw] [ARG1: the stapler] [ARGM-MNR: with my eyes] .
# 3  [ARG0: I] [V: saw] [ARG1: the toothpaste] [ARGM-MNR: with my eyes] .
# 4      [ARG0: I] [V: saw] [ARG1: the toilet] [ARGM-MNR: with my eyes] .
#
#             1
# 0  I-ARGM-MNR
# 1  I-ARGM-MNR
# 2  I-ARGM-MNR
# 3  I-ARGM-MNR
# 4  I-ARGM-MNR

# %%
df_pp[1].value_counts()
# Out:
# I-ARGM-MNR    153
# I-ARG2         15
# I-ARG1         12
# Name: 1, dtype: int64

# %%
int(len(df_pp[df_pp[1]!='I-ARGM-MNR'])/len(df_pp)*100)
# Out:
# 15

# %%
df_pp[df_pp[1]!='I-ARGM-MNR']
# Out:
#                                               0  \
# 93           I heard the umbrella with my ears.
# 94         I heard the toothpaste with my ears.
# 97      I heard the ornate mirror with my ears.
# 99         I heard the toothbrush with my ears.
# 100             I heard the knife with my ears.
# 109              I heard the fork with my ears.
# 111      I heard the spray bottle with my ears.
# 130    I heard the tape dispenser with my ears.
# 132           I heard the stapler with my ears.
# 137      I tasted the footstool with my tongue.
# 139     I tasted the toothbrush with my tongue.
# 142           I tasted the shoe with my tongue.
# 145       I tasted the umbrella with my tongue.
# 146         I tasted the toilet with my tongue.
# 153   I tasted the refrigerator with my tongue.
# 157        I tasted the stapler with my tongue.
# 163          I tasted the knife with my tongue.
# 176         I tasted the hammer with my tongue.
# 179  I tasted the standing lamp with my tongue.
#
#                                                                pp_tag       1  \
# 93           [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 94           [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 97   [B-ARG0, B-V, B-ARG2, I-ARG2, I-ARG2, B-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 99           [B-ARG0, B-V, B-ARG2, I-ARG2, B-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 100          [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 109          [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 111  [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 130  [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 132          [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, I-ARG1, I-ARG1, O]  I-ARG1
# 137          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 139          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 142          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 145          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 146          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 153          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 157          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 163          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 176          [B-ARG0, B-V, B-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
# 179  [B-ARG0, B-V, B-ARG1, I-ARG1, I-ARG1, B-ARG2, I-ARG2, I-ARG2, O]  I-ARG2
#
#                                                                      pp_descr
# 93                   [ARG0: I] [V: heard] [ARG1: the umbrella with my ears] .
# 94                 [ARG0: I] [V: heard] [ARG1: the toothpaste with my ears] .
# 97      [ARG0: I] [V: heard] [ARG2: the ornate mirror] [ARG1: with my ears] .
# 99         [ARG0: I] [V: heard] [ARG2: the toothbrush] [ARG1: with my ears] .
# 100                     [ARG0: I] [V: heard] [ARG1: the knife with my ears] .
# 109                      [ARG0: I] [V: heard] [ARG1: the fork with my ears] .
# 111              [ARG0: I] [V: heard] [ARG1: the spray bottle with my ears] .
# 130            [ARG0: I] [V: heard] [ARG1: the tape dispenser with my ears] .
# 132                   [ARG0: I] [V: heard] [ARG1: the stapler with my ears] .
# 137      [ARG0: I] [V: tasted] [ARG1: the footstool] [ARG2: with my tongue] .
# 139     [ARG0: I] [V: tasted] [ARG1: the toothbrush] [ARG2: with my tongue] .
# 142           [ARG0: I] [V: tasted] [ARG1: the shoe] [ARG2: with my tongue] .
# 145       [ARG0: I] [V: tasted] [ARG1: the umbrella] [ARG2: with my tongue] .
# 146         [ARG0: I] [V: tasted] [ARG1: the toilet] [ARG2: with my tongue] .
# 153   [ARG0: I] [V: tasted] [ARG1: the refrigerator] [ARG2: with my tongue] .
# 157        [ARG0: I] [V: tasted] [ARG1: the stapler] [ARG2: with my tongue] .
# 163          [ARG0: I] [V: tasted] [ARG1: the knife] [ARG2: with my tongue] .
# 176         [ARG0: I] [V: tasted] [ARG1: the hammer] [ARG2: with my tongue] .
# 179  [ARG0: I] [V: tasted] [ARG1: the standing lamp] [ARG2: with my tongue] .

# %%
def make_data_pp_attachment(amount_per_format):
    list_pp_attachment = []

    editor = Editor()
    test_data = editor.template("I saw the man with the {mask}.",
                                list_objects = list_objects,
                                meta=True, seed=42,  
                                nsamples=amount_per_format,
                                remove_duplicates=True)
    list_pp_attachment.append(test_data['data'])
    list_pp_attachment = [x for xs in list_pp_attachment for x in xs]
    return list_pp_attachment
list_pp_attachment_arg1 = make_data_pp_attachment(200)

# %%
df_pp_arg1 = pd.DataFrame(list_pp_attachment_arg1)
df_pp_arg1['pp_tag'] = df_pp_arg1[0].apply(get_pp_tags)
df_pp_arg1['pp_descr'] = df_pp_arg1[0].apply(get_pp_descr)

# %%
df_pp_arg1.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8v/s7d6dz912f93j_c9dwn7szt80000gn/T/ipykernel_42232/47974339.py in <module>
# ----> 1 df_pp
#
# NameError: name 'df_pp' is not defined

# %%
def find_final_min_one_arg(list_of_arg):
    return list_of_arg[-2]

df_pp_arg1[1] = df_pp_arg1['pp_tag'].apply(find_final_min_one_arg)

# %%
df_pp_arg1[1].value_counts()
# Out:
# I-ARG1    200
# Name: 1, dtype: int64
